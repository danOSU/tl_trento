# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
D2_trento_design = pd.read_csv('2D_500POINTS_rescaled.txt', header=0, names=['N', 'w', r'$\chi$'])
D3_trento_design = pd.read_csv('3D_150POINTS_rescaled.txt', header=0, names=['N', 'w', r'$\chi$', r'k$_{T,min}$', 
                                                                             r'$\alpha$', r'$\beta$', 'flatness'])

# %%
D2_trento_design.head()
# Out:
#            N         w  $\chi$
# 0   9.011875  0.791656  0.5865
# 1   9.391875  0.911094  0.7025
# 2   9.819375  1.232656  0.4935
# 3  10.389375  1.201156  0.2815
# 4  10.674375  0.615781  0.2395

# %%
D3_trento_design.head()
# Out:
#            N         w  $\chi$  k$_{T,min}$  $\alpha$   $\beta$  flatness
# 0   9.011875  0.791656  0.5865     0.202667  3.562222  0.191111  1.105000
# 1   9.391875  0.911094  0.7025     0.216889  4.162222  1.315556  1.368333
# 2   9.819375  1.232656  0.4935     0.234667  4.491111 -0.213333  1.061667
# 3  10.389375  1.201156  0.2815     0.248889  3.926667  0.608889  1.159444
# 4  10.674375  0.615781  0.2395     0.266667  3.735556  0.346667  1.285000

# %%
D2_trento_design.shape
# Out:
# (500, 3)

# %%
D3_trento_design.shape
# Out:
# (150, 7)

# %% [markdown]
# # Let's make some plots

# %%
sns.set_context('talk')

# %%
sns.pairplot(D2_trento_design)

# %%
for samples in [50,100,150]:
    sns.pairplot(D3_trento_design.iloc[0:samples])
