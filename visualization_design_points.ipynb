# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
D2_trento_design = pd.read_csv('2D_500POINTS_rescaled.txt', header=0, names=['N', 'w', r'$\chi$'])
D3_trento_design = pd.read_csv('3D_150POINTS_rescaled.txt', header=0, names=['N', 'w', r'$\chi$', r'k$_{T,min}$', 
                                                                             r'$\alpha$', r'$\beta$', 'flatness'])

# %%
D2_trento_design.head()
# Out:
#            N         w  $\chi$
# 0   9.178125  0.588219  0.7645
# 1   9.439375  0.737844  0.3095
# 2   9.866875  1.308781  0.7325
# 3  10.151875  0.607906  0.5705
# 4  10.816875  0.947844  0.5465

# %%
D3_trento_design.head()
# Out:
#            N         w  $\chi$  k$_{T,min}$  $\alpha$   $\beta$  flatness
# 0   9.178125  0.588219  0.7645     0.861035  4.613635  0.339129  1.419209
# 1   9.439375  0.737844  0.3095     0.840746  3.350621  0.496663  1.382454
# 2   9.866875  1.308781  0.7325     0.629186  4.533852  1.119447  1.374333
# 3  10.151875  0.607906  0.5705     0.459554  3.565454 -0.289346  1.101547
# 4  10.816875  0.947844  0.5465     0.734829  3.897851  0.050244  1.381457

# %%
D2_trento_design.shape
# Out:
# (500, 3)

# %%
D3_trento_design.shape
# Out:
# (150, 7)

# %% [markdown]
# # Let's make some plots

# %%
sns.set_context('talk')

# %%
sns.pairplot(D2_trento_design)

# %%
for samples in [50,100,150]:
    sns.pairplot(D3_trento_design.iloc[0:samples])
